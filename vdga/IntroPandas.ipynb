# %% [markdown]
# # Introducción a Pandas
#
# Importamos pandas y le otorgamos un alias

# %%
import pandas as pd

# %% [markdown]
# ### Importar nuestros datos
#     Para importar nuestris datis y usarlos como DataFrames de pandas, usaremos la siguiente función:

# %%
df = pd.read_csv("C:/Users/Ontwice/Documents/Master/master-data/vdga/IN/vgsales.csv")

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
# df.head()
# df.tail()
# df.describe()
# df.info()
# df.shape
# df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
inverted_df = df.sort_values("Rank", ascending = False)

inverted_df
# Out:
#         Rank                                              Name Platform  \
# 16597  16600                                  Spirits & Spells      GBA
# 16596  16599                                        Know How 2       DS
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# ...      ...                                               ...      ...
# 4          5                          Pokemon Red/Pokemon Blue       GB
# 3          4                                 Wii Sports Resort      Wii
# 2          3                                    Mario Kart Wii      Wii
# 1          2                                 Super Mario Bros.      NES
# 0          1                                        Wii Sports      Wii
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
selected_cols = ["Platform","Name", "Global_Sales"] 
sub_df = df[selected_cols]

# %%
filter = sub_df["Global_Sales"] < 1

sub_df[filter]
# Out:
#       Platform                                              Name  Global_Sales
# 2081      X360                                      Dead Space 3          0.99
# 2082        DS                      Phoenix Wright: Ace Attorney          0.99
# 2083        XB                                    NFL Fever 2002          0.99
# 2084        GC                           The Simpsons: Hit & Run          0.99
# 2085        DS                         Littlest Pet Shop: Winter          0.99
# ...        ...                                               ...           ...
# 16593      GBA                Woody Woodpecker in Crazy Castle 5          0.01
# 16594       GC                     Men in Black II: Alien Escape          0.01
# 16595      PS2  SCORE International Baja 1000: The Official Game          0.01
# 16596       DS                                        Know How 2          0.01
# 16597      GBA                                  Spirits & Spells          0.01
#
# ...
